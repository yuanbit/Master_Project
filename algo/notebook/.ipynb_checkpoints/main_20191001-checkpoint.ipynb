# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import sys
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import csv
from collections import Counter
import matplotlib.cm as cm
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import DBSCAN
from sklearn.cluster import MeanShift
from itertools import chain, combinations
from sklearn.cluster import SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.cluster import Birch
import itertools
import time
from sklearn.cluster import AffinityPropagation
import re

def decode(labels):
    encoding = 'utf-8'

    # decode from byte to string
    labels = [str(x, encoding) for x in labels]
    label_decoded = [x.replace('_', ' ') for x in labels]
    
    return label_decoded

def get_labels_idx(keys, raw_labels):
    # key: category
    # value: index
    
    labels = {}

    for i in range(len(raw_labels)):
        for k in keys:
            if k in raw_labels[i]:
                if k not in labels:
                    labels[k] = [i]
                else:
                    labels[k].append(i)
                    
    return labels

def get_clusters_dict(labels):
    # key: label
    # value: indices of images
    clusters = {}

    for idx, label in enumerate(labels):
        if label not in clusters:
            # The label is seen for first time, create a new list.
            clusters[label] = [idx]
        else:
            clusters[label].append(idx)
            
    return clusters

# Create label pairs

def create_label_pairs(labels):
    
    label_pairs = {}
    
    for key, value in labels.items():
        label_pairs[key] = list(itertools.combinations(value, 2)) 
        
    label_pairs_concat = []

    for key, value in label_pairs.items():
        label_pairs_concat += value
        
    return label_pairs_concat

# F-measure

def f_measure(true_labels, cluster_labels, algo):
    
    true_positive = list(set(true_labels).intersection(cluster_labels))
    false_positive = list(set(cluster_labels) - set(true_labels))
    false_negative = list(set(true_labels) - set(cluster_labels))

    TP = len(true_positive)
    FP = len(false_positive)
    FN = len(false_negative)
    
    precision = round(TP/(TP+FP), 3)
    
    recall = round(TP/(TP+FN), 3)
    
    f_measure = round(2*((precision*recall)/(precision+recall)), 3)
    
    print("{} F-Measure: {}".format(algo, f_measure))
    print("{} Precision: {}".format(algo, precision))
    print("{} Recall: {}".format(algo, recall))
    print("{} Number of False Positives: {}".format(algo, FP))

# %%
# read in embeddings from ArcFace

arcface_embeddings = np.load("embeddings/ex2_arcface/embeddings.npy")
arcface_raw_labels = np.load("embeddings/ex2_arcface/names.npy")
arcface_raw_labels = decode(arcface_raw_labels)
arcface_raw_labels = [re.sub(".png", "", x) for x in arcface_raw_labels]
arcface_raw_labels = [re.sub(".jpg", "", x) for x in arcface_raw_labels]

print(arcface_embeddings.shape)
print(arcface_raw_labels)
# Out:
# (2199, 512)
# ['Davy Fitzgerald manager', 'Arno Berg architect', 'Wilhelm Swensen architect', 'Fyodor Schechtel architect', 'Carlos Payán politician', 'Traugott Bardt architect', 'Artem Ermolaev manager', 'Aleksey Gubry military officer', 'David Evans manager', 'Maksim Atayants architect', 'GastonSILVA soccer', 'Archibald Simpson architect', 'Noach Dear politician', 'MatthiasGINTER soccer', 'George Parker Bidder architect', 'SebastianCOATES soccer', 'MiguelTRAUCO soccer', 'Paul Sanders politician', 'Peter Terryn politician', 'Thomas Gage military officer', 'Geir Olsen politician', 'Daniel M. Frost military officer', 'Ben Noteboom manager', 'Alexei Beketov architect', 'James Alesi politician', 'Dragan Tomić politician', 'George Spencer, 4th Duke of Marlborough military officer', 'Hagbarth Martin Schytte-Berg architect', 'Bernt Heiberg architect', 'Ilja Šmíd manager', 'MilanRODIC soccer', 'Anton Ferjančič military officer', 'John Ruskin architect', 'Ferdinand Janež military officer', 'John George Howard architect', 'MarcoREUS soccer', 'Albert Statz politician', 'Nikola Dobrovic architect', 'Ioan Niculae manager', 'Mark B. Childress politician', 'Stefano Parisi manager', 'Dominic Oldman manager', 'Taha Genc politician', 'Boris Podrecca architect', 'Asen Pilev politician', 'AzizBEHICH soccer', 'Ivan Zaïtsev military officer', 'Franz von Mercy military officer', 'Hansjörg Schmidt politician', 'Christian Grimsgaard military officer', 'Evgeny Ass architect', 'Petr Bajer politician', 'Augustine Prévost military officer', 'Bart Snels politician', 'John Jervis, 1st Earl of St Vincent military officer', 'MARIORUI soccer', 'Martin Winterkorn manager', 'William Cornwallis military officer', 'Humpy Wheeler manager', 'Manuel Dios Diz politician', 'Andrew Falk politician', 'Johan Meyer architect', 'P. W. Singer politician', 'MartinSILVA soccer', 'John Belcher architect', 'Edward Pakenham military officer', 'Fritz Holland architect', 'Thomas Telford architect', 'Dieter Spethmann manager', 'Paul Armin Due architect', 'Nikolay Bespalov architect', 'Alfred Pfalzgraf politician', 'Vladimir Malanin manager', 'EduardoSALVIO soccer', 'John Vanbrugh architect', 'Alupa Clarke politician', 'Henry Farnam manager', 'Albert Botran politician', 'Ivan Erdélyi military officer', 'Kristofer Lange architect', 'Matthew Digby Wyatt architect', 'Miklós Horthy military officer', 'ArtemDZYUBA soccer', 'Justin Simmons politician', 'Thomas Engelke manager', 'Hermann Hartleb politician', 'Emil Rebreanu military officer', 'MesutOEZIL soccer', 'RafalKURZAWA soccer', 'Reginald Blomfield architect', 'LukaszFABIANSKI soccer', 'MatiasVECINO soccer', 'Hansgünter Matuschak manager', 'Roman Petrenko manager', 'Anthony George Lyster architect', 'Pavel Kallinikov manager', 'Clive Doucet politician', 'Gavriil Ter-Mikelov architect', 'Francis Nicholson military officer', 'Lars Witteck politician', 'Pedro Carrizales politician', 'Geert van den Boomen manager', 'Edmund Kirby Smith military officer', 'Vasily Chuikov military officer', 'Johannes Klingenberg Sejersted military officer', 'Andrei Razin manager', 'CASSIO soccer', 'BETO soccer', 'Bjørnar Skjevik manager', 'Georg Ulrich Wasmuth military officer', 'Mats Pilhem politician', 'Johann von Hlavaty military officer', 'Alejandro Echevarría Busquet manager', 'ThorganHAZARD soccer', 'Claus Hjelte architect', 'Helmuth Groscurth military officer', 'Isaac Ware architect', 'Aleksey Brusilov military officer', 'Sir John Ormsby Vandeleur military officer', 'Hans-Georg Härter manager', 'Pavel Alyoshin architect', 'József Sas manager', 'Uroš Čufer politician', 'Chris Monzel manager', 'Daniel Ben-Horin manager', 'Jonathan Marland, Baron Marland manager', 'William Tryon military officer', 'Miguel Tellado politician', 'YouriTIELEMANS soccer', 'Valery Petrov manager', 'Dušan Meničanin military officer', 'Benigno Blanco politician', 'William Morris architect', 'Eduard Khudainatov manager', 'Carl Johan Anker military officer', 'JaimePENEDO soccer', 'Juergen Boos ...

# %%
# read in embeddings from dlib

dlib_embeddings = np.load("embeddings/experiment2/dlib/ex2_dlib_embeddings.npy")
dlib_raw_labels = np.load("embeddings/experiment2/dlib/ex2_dlib_names.npy")
dlib_raw_labels = [re.sub(".png", "", x) for x in dlib_raw_labels]
dlib_raw_labels = [re.sub(".jpg", "", x) for x in dlib_raw_labels]
dlib_raw_labels = [re.sub("_", " ", x) for x in dlib_raw_labels]

print(dlib_embeddings.shape)

print(dlib_raw_labels)
# Out:
# (2065, 128)
# ['Davy Fitzgerald manager', 'Arno Berg architect', 'Wilhelm Swensen architect', 'Fyodor Schechtel architect', 'Carlos Payán politician', 'Traugott Bardt architect', 'Artem Ermolaev manager', 'Aleksey Gubry military officer', 'David Evans manager', 'Maksim Atayants architect', 'GastonSILVA soccer', 'Archibald Simpson architect', 'Noach Dear politician', 'MatthiasGINTER soccer', 'George Parker Bidder architect', 'SebastianCOATES soccer', 'MiguelTRAUCO soccer', 'Paul Sanders politician', 'Peter Terryn politician', 'Thomas Gage military officer', 'Geir Olsen politician', 'Daniel M. Frost military officer', 'Ben Noteboom manager', 'James Alesi politician', 'Dragan Tomić politician', 'George Spencer, 4th Duke of Marlborough military officer', 'Hagbarth Martin Schytte-Berg architect', 'Bernt Heiberg architect', 'Ilja Šmíd manager', 'MilanRODIC soccer', 'Anton Ferjančič military officer', 'John Ruskin architect', 'Ferdinand Janež military officer', 'John George Howard architect', 'MarcoREUS soccer', 'Albert Statz politician', 'Nikola Dobrovic architect', 'Ioan Niculae manager', 'Mark B. Childress politician', 'Stefano Parisi manager', 'Dominic Oldman manager', 'Taha Genc politician', 'Boris Podrecca architect', 'Asen Pilev politician', 'AzizBEHICH soccer', 'Ivan Zaïtsev military officer', 'Franz von Mercy military officer', 'Hansjörg Schmidt politician', 'Christian Grimsgaard military officer', 'Evgeny Ass architect', 'Petr Bajer politician', 'Augustine Prévost military officer', 'Bart Snels politician', 'John Jervis, 1st Earl of St Vincent military officer', 'MARIORUI soccer', 'Martin Winterkorn manager', 'William Cornwallis military officer', 'Humpy Wheeler manager', 'Manuel Dios Diz politician', 'Andrew Falk politician', 'Johan Meyer architect', 'P. W. Singer politician', 'MartinSILVA soccer', 'Edward Pakenham military officer', 'Fritz Holland architect', 'Thomas Telford architect', 'Dieter Spethmann manager', 'Paul Armin Due architect', 'Nikolay Bespalov architect', 'Alfred Pfalzgraf politician', 'Vladimir Malanin manager', 'EduardoSALVIO soccer', 'John Vanbrugh architect', 'Alupa Clarke politician', 'Henry Farnam manager', 'Albert Botran politician', 'Ivan Erdélyi military officer', 'Kristofer Lange architect', 'Matthew Digby Wyatt architect', 'Miklós Horthy military officer', 'ArtemDZYUBA soccer', 'Justin Simmons politician', 'Hermann Hartleb politician', 'Emil Rebreanu military officer', 'MesutOEZIL soccer', 'RafalKURZAWA soccer', 'Reginald Blomfield architect', 'LukaszFABIANSKI soccer', 'MatiasVECINO soccer', 'Hansgünter Matuschak manager', 'Roman Petrenko manager', 'Anthony George Lyster architect', 'Pavel Kallinikov manager', 'Clive Doucet politician', 'Gavriil Ter-Mikelov architect', 'Francis Nicholson military officer', 'Lars Witteck politician', 'Pedro Carrizales politician', 'Edmund Kirby Smith military officer', 'Vasily Chuikov military officer', 'CASSIO soccer', 'BETO soccer', 'Bjørnar Skjevik manager', 'Georg Ulrich Wasmuth military officer', 'Mats Pilhem politician', 'Johann von Hlavaty military officer', 'Alejandro Echevarría Busquet manager', 'ThorganHAZARD soccer', 'Claus Hjelte architect', 'Helmuth Groscurth military officer', 'Isaac Ware architect', 'Sir John Ormsby Vandeleur military officer', 'Hans-Georg Härter manager', 'Pavel Alyoshin architect', 'József Sas manager', 'Uroš Čufer politician', 'Chris Monzel manager', 'Daniel Ben-Horin manager', 'Jonathan Marland, Baron Marland manager', 'William Tryon military officer', 'Miguel Tellado politician', 'YouriTIELEMANS soccer', 'Valery Petrov manager', 'Dušan Meničanin military officer', 'Benigno Blanco politician', 'William Morris architect', 'Eduard Khudainatov manager', 'Carl Johan Anker military officer', 'JaimePENEDO soccer', 'Juergen Boos manager', 'Michael Kemmer manager', 'Frode Rinnan architect', 'Robert E. Lee military officer', 'Martin Hinshelwood manager', 'JamieVARDY soccer', 'Enrico Nordio architect', 'Pavel Krtek manager', 'Sir Peter Parker, 2nd Bar ...

# %%
# read in embeddings from Openface

data = list(csv.reader(open("embeddings/experiment3/openface/reps.csv")))
label_s = list(csv.reader(open("embeddings/experiment3/openface/labels.csv")))

# data = list(csv.reader(open("embeddings/data1_mtcnn_160_openface/reps.csv")))
# label_s = list(csv.reader(open("embeddings/data1_mtcnn_160_openface/labels.csv")))

openface_embeddings = np.asarray(data, dtype=float)
openface_raw_labels = []

for i in range(len(label_s)):
    openface_raw_labels.append(label_s[i][1])

#openface_raw_labels = [re.sub("./datasets/data1_aligned/", "", x) for x in openface_raw_labels]
#openface_raw_labels = [re.sub("./datasets/data1_mtcnnpy_160/", "", x) for x in openface_raw_labels]
openface_raw_labels = [re.sub("./datasets/openface_aligned/", "", x) for x in openface_raw_labels]
openface_raw_labels = [re.sub("(?=\/).*$", "", x) for x in openface_raw_labels]
openface_raw_labels = [re.sub("_", " ", x) for x in openface_raw_labels]

print(openface_embeddings.shape)
print(openface_raw_labels)
# Out:
# (4609, 128)
# ['Davy Fitzgerald manager', 'Arno Berg architect', 'Jan Josef Liefers actor', 'Wilhelm Swensen architect', 'Fyodor Schechtel architect', 'Cub Swanson fighter', 'Atle Antonsen entrepreneur', 'Vladimir Gomelsky coach', 'Vladimir Putin coach', 'David Cronenberg entrepreneur', 'Rudiger Oppermann musician', 'Traugott Bardt architect', 'Drilon Cocaj entrepreneur', 'Vyacheslav Tikhonov entrepreneur', 'Phil Hansel coach', 'Artem Ermolaev manager', 'Stephen Ackles actor', 'Aleksey Gubry military officer', 'David Evans manager', 'Maksim Atayants architect', 'GastonSILVA soccer', 'Alan Bern musician', 'Aiden Jude musician', 'Archibald Simpson architect', 'Branko Paic musician', 'Noach Dear politician', 'MatthiasGINTER soccer', 'Felipe Silva fighter', 'George Parker Bidder architect', 'Jasenko Omanovic politician', 'Benito Lopez fighter', 'SebastianCOATES soccer', 'Demetrious Johnson fighter', 'Rade Serbedzija actor', 'JR Bourne actor', 'Chad Laprise fighter', 'Rezo Chkheidze entrepreneur', 'Daniel Kagan lawyer', 'David Sutcliffe entrepreneur', 'Eugene Levy actor', 'Armando Rodriguez Ruidiaz musician', 'MiguelTRAUCO soccer', 'Paul Sanders politician', 'Peter Terryn politician', 'Thomas Gage military officer', 'Uli Konig politician', 'Geir Olsen politician', 'Daniel M. Frost military officer', 'Thomas J. Whelan lawyer', 'Igor Kvasha actor', 'Per Aabel actor', 'Ben Noteboom manager', 'Thomas Almeida fighter', 'James Alesi politician', 'Stephen LeDrew lawyer', 'George Sullivan fighter', 'Charlie Mars musician', 'Mikhail Zharov entrepreneur', 'George Spencer, 4th Duke of Marlborough military officer', 'Peter Radberg politician', 'Hagbarth Martin Schytte-Berg architect', 'Stig Rune Kveen coach', 'Bernt Heiberg architect', 'Julien Kang entrepreneur', 'Siyar Bahadurzada fighter', 'Edison Chen entrepreneur', 'Alan Heisey lawyer', 'Tahmoh Penikett entrepreneur', 'Valery Gazzaev coach', 'Nikolai Fomenko actor', 'MilanRODIC soccer', 'Joze Mesar architect', 'John Ruskin architect', 'Slavko Stimac actor', 'Bill Mockridge entrepreneur', 'Matija Barl actor', 'Marvin Vettori fighter', 'John George Howard architect', 'Georges St-Pierre actor', 'MarcoREUS soccer', 'Albert Statz politician', 'Ronald Nemec lawyer', 'Nikola Dobrovic architect', 'Kjell Ake Modeer lawyer', 'Michael J. McShane lawyer', 'Sergey Bezrukov actor', 'Edvard Drablos actor', 'Carl Barbier lawyer', 'Anatoly Lunacharsky entrepreneur', 'Ioan Niculae manager', 'Mark B. Childress politician', 'Stefano Parisi manager', 'Dominic Oldman manager', 'Taha Genc politician', 'Rudiger Scholz politician', 'Boris Podrecca architect', 'Kris Holden-Ried actor', 'Georgij Kaminski coach', 'Alfred Otsch manager', 'Asen Pilev politician', 'Michael Chiesa fighter', 'William Daroff lawyer', 'AzizBEHICH soccer', 'Marcelo Golm fighter', 'Krzysztof Jotko fighter', 'Rainer Erlinger lawyer', 'Brian Kelly coach', 'Evgeniy Tsymbal actor', 'Franz von Mercy military officer', 'Brandon Moreno fighter', 'Christian Grimsgaard military officer', 'Evgeny Ass architect', 'Benedict Taylor musician', 'Petr Bajer politician', 'Tyson Pedro fighter', 'Sverre Kjelsberg entrepreneur', 'Sergey Rost entrepreneur', 'Yves Berton musician', 'Alex Morono fighter', 'Roger Williams coach', 'Wilhelm Hansen Faerden military officer', 'Innokenty Smoktunovsky entrepreneur', 'Vyacheslav Shchyogolev coach', 'Kevin McDonald entrepreneur', 'Stephen Lobo actor', 'Henning Ottersen coach', 'Keene Fitzpatrick coach', 'Bart Snels politician', 'John Jervis, 1st Earl of St Vincent military officer', 'MARIORUI soccer', 'Mike Pyle fighter', 'Martin Winterkorn manager', 'Armen Dzhigarkhanyan actor', 'Giovanni Caprara coach', 'Ismail Emrah Karayel lawyer', 'Thomas Nihlen politician', 'William Cornwallis military officer', 'Humpy Wheeler manager', 'Takanori Gomi fighter', 'Sam Alvey fighter', 'Jeremy Bash lawyer', 'Manuel Dios Diz politician', 'Andrew Falk politician', 'John Castaneda fighter', 'Lorne Greene entrepreneur', 'John D. Trasvina lawyer', 'Johan Me ...

# %%
# read in embeddings from FaceNet",

facenet_embeddings = np.load("embeddings/ex2_2_facenet/embeddings.npy")
label_strings = np.load("embeddings/ex2_2_facenet/label_strings.npy")
facenet_raw_labels = decode(label_strings)
#facenet_raw_labels = [re.sub("convict", " convict", x) for x in facenet_raw_labels]

print(facenet_embeddings.shape)

print(facenet_raw_labels[0])
# Out:
# (2199, 512)
# ABDALLASAID soccer

# %%
## Starting clustering and evaluation

#keys = ["tennis", "basketball", "golf", "fighter", "soccer"]
# keys = ["tennis", "basketball", "golf", "fighter", "soccer", \
#         "actor", "artist", "businessperson", "computer scientist", \
#         "convict", "musician", "philosopher", "physician", "politician", "writer"]

# keys = ["tennis", "basketball", "golf", "fighter", "soccer", \
#         "businessperson", "computer scientist", \
#         "convict", "physician", "politician", "writer", \
#         "military officer", "judge", "film producer", "conductor", "painter"]

# keys = ["military officer", "judge", "soccer", "coach", \
#         "manager", "politician", "conductor", "actor", "architect", \
#        "fighter", "entrepreneur"]

# keys = [ "soccer", "manager", "politician", \
#         "coach", "actor", "military officer", "architect"]

keys = ["military officer", "politician", \
       "manager", "soccer", "architect", \
       "coach", "actor", "lawyer", "entrepreneur", "fighter", "musician"]

# Get label/index dictionary
facenet_labels = get_labels_idx(keys, facenet_raw_labels)
openface_labels = get_labels_idx(keys, openface_raw_labels)
dlib_labels = get_labels_idx(keys, dlib_raw_labels)
arcface_labels = get_labels_idx(keys, arcface_raw_labels)

# Choose method
feature_extraction_method = "openface"

if feature_extraction_method == "openface":

    X = openface_embeddings
    # Create ground truth pairs for evaulation
    true_label_pairs = create_label_pairs(openface_labels)
    
elif feature_extraction_method == "facenet":
    
    X = facenet_embeddings
    # Create ground truth pairs for evaulation
    true_label_pairs = create_label_pairs(facenet_labels)

elif feature_extraction_method == "dlib":
    
    X = dlib_embeddings
    # Create ground truth pairs for evaulation
    true_label_pairs = create_label_pairs(dlib_labels)
    
elif feature_extraction_method == "arcface":
    
    X = arcface_embeddings
    # Create ground truth pairs for evaulation
    true_label_pairs = create_label_pairs(arcface_labels)

# %%
# c = 0
# for key, value in facenet_labels.items():
#     print(key)
#     print(len(value))
#     c+=len(value)
    
# print(c)

# print(len(facenet_labels))

# print()

# c = 0
# for key, value in arcface_labels.items():
#     print(key)
#     print(len(value))
#     c+=len(value)
    
# print(c)

# print(len(arcface_labels))

# print()

c = 0
for key, value in openface_labels.items():
    print(key)
    print(len(value))
    c+=len(value)
    
print(c)

print(len(openface_labels))


# print()

# c = 0
# for key, value in dlib_labels.items():
#     print(key)
#     print(len(value))
#     c+=len(value)
    
# print(c)

# print(len(dlib_labels))
# Out:
# manager
# 371
# architect
# 388
# actor
# 413
# fighter
# 537
# entrepreneur
# 485
# coach
# 340
# musician
# 375
# military officer
# 407
# soccer
# 450
# politician
# 449
# lawyer
# 394
# 4609
# 11

# %%
# K-means 
num_clusters = 11

start_time = time.time()

kmeans = KMeans(n_clusters = num_clusters).fit(X)
#print(kmeans.labels_)

k_means_clusters = get_clusters_dict(kmeans.labels_)

# print(labels)
# print("\n")
# print(k_means_clusters)

kmeans_label_pairs = create_label_pairs(k_means_clusters)

#F-measure

f_measure(true_label_pairs, kmeans_label_pairs, "K-means")

print("--- %s seconds ---" % (time.time() - start_time))

print()

# Hierarchical Agglomerative Clustering

start_time = time.time()

clustering = AgglomerativeClustering(n_clusters=num_clusters, distance_threshold=None).fit(X)
hac_clusters = get_clusters_dict(clustering.labels_)

hac_label_pairs = create_label_pairs(hac_clusters)

f_measure(true_label_pairs, hac_label_pairs, "HAC")

print("--- %s seconds ---" % (time.time() - start_time))

print()


# Spectral Clustering

start_time = time.time()

clustering = SpectralClustering(n_clusters=num_clusters).fit(X)

spectral_cluster = get_clusters_dict(clustering.labels_)

spectral_label_pairs = create_label_pairs(spectral_cluster)

f_measure(true_label_pairs, spectral_label_pairs, "Spectral")

print("--- %s seconds ---" % (time.time() - start_time))

print()

# Gaussian Mixture EM

start_time = time.time()

gmm_labels = GaussianMixture(n_components=num_clusters, init_params='kmeans').fit_predict(X)

gmm_clusters = get_clusters_dict(gmm_labels)

gmm_label_pairs = create_label_pairs(gmm_clusters)

f_measure(true_label_pairs, gmm_label_pairs, "GMM")

print("--- %s seconds ---" % (time.time() - start_time))

print()

# Birch

start_time = time.time()

brc = Birch(n_clusters=num_clusters, compute_labels=True).fit(X) 

birch_labels = brc.predict(X)

birch_clusters = get_clusters_dict(birch_labels)

birch_label_pairs = create_label_pairs(birch_clusters)

f_measure(true_label_pairs, birch_label_pairs, "Birch")

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# K-means F-Measure: 0.135
# K-means Precision: 0.133
# K-means Recall: 0.138
# K-means Number of False Positives: 882316
# --- 2.646676540374756 seconds ---
#
# HAC F-Measure: 0.14
# HAC Precision: 0.135
# HAC Recall: 0.146
# HAC Number of False Positives: 913705
# --- 2.547563076019287 seconds ---
#
# Spectral F-Measure: 0.131
# Spectral Precision: 0.13
# Spectral Recall: 0.133
# Spectral Number of False Positives: 873364
# --- 5.109647035598755 seconds ---
#
# GMM F-Measure: 0.147
# GMM Precision: 0.144
# GMM Recall: 0.15
# GMM Number of False Positives: 871486
# --- 3.220937490463257 seconds ---
#
# Birch F-Measure: 0.141
# Birch Precision: 0.131
# Birch Recall: 0.152
# Birch Number of False Positives: 984786
# --- 1.6809980869293213 seconds ---

# %%
# Find error pairs

true_positive = list(set(true_label_pairs).intersection(hac_label_pairs))
false_positive = list(set(hac_label_pairs) - set(true_label_pairs))
false_negative = list(set(true_label_pairs) - set(hac_label_pairs))

print(false_positive[:100])

f = false_positive[:100]
# Out:
# [(1531, 3553), (2538, 2974), (2044, 2237), (588, 1914), (535, 3421), (290, 4065), (1032, 4489), (4271, 4584), (3348, 4324), (1378, 3559), (1654, 4212), (1459, 3142), (2845, 4467), (650, 1583), (3286, 3827), (1263, 3817), (934, 4667), (97, 4096), (1604, 1771), (2611, 3326), (1551, 2540), (22, 761), (3155, 4093), (3214, 3930), (1110, 2279), (3298, 4844), (865, 2951), (1654, 2528), (125, 1275), (4095, 4742), (1735, 3957), (1303, 1584), (206, 3664), (1334, 4219), (2804, 3732), (2034, 3610), (525, 3772), (2167, 4149), (2816, 3504), (2012, 2734), (3398, 3533), (1122, 1752), (3636, 3854), (2413, 4033), (2673, 3368), (1613, 3842), (2494, 4398), (4607, 4741), (165, 850), (1881, 2854), (464, 3065), (977, 3761), (3441, 5039), (3388, 4242), (955, 1473), (1541, 3627), (12, 90), (1415, 4102), (215, 1725), (578, 4619), (759, 1440), (3123, 3436), (2160, 3918), (2241, 4607), (3472, 3851), (1159, 3457), (1725, 3540), (308, 1075), (1008, 4690), (3522, 4656), (3366, 3730), (2403, 2432), (74, 3852), (2641, 3903), (587, 3066), (155, 1329), (3028, 4392), (3185, 3258), (668, 4429), (565, 1222), (1952, 2846), (833, 866), (401, 3525), (3037, 4625), (4232, 4472), (3726, 4464), (3913, 4527), (1014, 2587), (945, 2048), (1221, 3623), (3735, 4777), (1734, 2659), (3922, 4208), (4391, 4691), (339, 1110), (3082, 3098), (1846, 2945), (3216, 4120), (524, 4904), (2166, 2691)]

# %%
for pair in f:
    print(facenet_raw_labels[pair[0]])
    print(facenet_raw_labels[pair[1]])
    print()
# Out:
# Forward243 basketball
# MoussaDEMBELE soccer
#
# Jon Mikl Thor actor m
# Leonardo León convict m
#
# Homi K. Bhabha philosopher m
# James Cameron actor m
#
# Bob Sowards golf
# Gyenge Zoltán philosopher m
#
# Bernat Vivancos i Farràs businessperson m
# Mieczysław Franaszek actor m
#
# Andre Landzaat actor m
# Ric Clark businessperson m
#
# Danny Roberts fighter
# SteveMANDANDA soccer
#
# Sadek Wahba businessperson m
# Taoufik Jebali actor m
#
# Mehdi Khazali physician m
# Saydulla Mamatqulov musician m
#
# Eugène Savitzkaya writer m
# Muhammad Fahim politician m
#
# Gary Hallberg golf
# Roy Arad artist m
#
# Florin Popențiu Vlădicescu computer scientist m
# Manuel Jorba i Jorba writer m
#
# Kevin Power writer m
# Stephan Hartmann philosopher m
#
# Brian Colon politician m
# Frank Fagan businessperson m
#
# Mathias Tegnér politician m
# Patton Kizzire golf
#
# Ed Dougherty golf
# Patrick Dixon businessperson m
#
# CristhianSTUANI soccer
# Tim Oliver Schultz actor m
#
# Ahmad Alirezabeighi politician m
# Rick Lamb golf
#
# François-Xavier Bossard musician m
# Greg Norman golf
#
# Josep Maria Esquirol philosopher m
# Max Eipp actor m
#
# Forward8 basketball
# Jon Rahm golf
#
# Aaron Seigo computer scientist m
# Carls John De Tomas fighter
#
# Marc Levoy computer scientist m
# Rick Fehr golf
#
# Mark Hensby golf
# Philipp Sonntag actor m
#
# David Solomon artist m
# Jan Hoogland philosopher m
#
# Matt Frevola fighter
# VincentKOMPANY soccer
#
# Chris Lattner computer scientist m
# Laxman Singh Gaur politician m
#
# Gary Hallberg golf
# Johny Hendricks fighter
#
# Alain Jaubert writer m
# Edi Majaron musician m
#
# Rick Hutton musician m
# Torstein Hagen businessperson m
#
# Giuseppe Fiori writer m
# Priit Valkna musician m
#
# Eival Gilady businessperson m
# Frank Land computer scientist m
#
# Alexander Stille writer m
# Nicolás Maduro convict m
#
# Emmanuel Tourpe philosopher m
# Rudi Studer computer scientist m
#
# Keith Fergus golf
# Olivier Morel artist m
#
# Hideki Tōjō convict m
# Nathan Green golf
#
# Benny Binion convict m
# P. W. Singer politician m
#
# J.T. Poston golf
# Robert Whittaker fighter
#
# Ken Kendrick businessperson m
# Mohammad Firouzi musician m
#
# HenrikDALSGAARD soccer
# Jörn-Felix Alt actor m
#
# Michael Walde-Berger actor m
# Morris Hatalsky golf
#
# Dean Hachamovitch computer scientist m
# Gorasek Khonin actor m
#
# Nic Romm actor m
# Paulo Silva politician m
#
# Jimmie Rivera fighter
# Raul Mondesi convict m
#
# Joxel García physician m
# Michael Devitt philosopher m
#
# Frederick Grinnell philosopher m
# Paul Laverty actor m
#
# John Gage computer scientist m
# Sheldon Westcott fighter
#
# Thangar Bachan actor m
# Tony Wegas convict m
#
# Alejandro Cañizares golf
# Chew Choon Seng businessperson m
#
# Guard79 basketball
# KhadimNDIAYE soccer
#
# Axl Rose convict m
# Luke Sanders fighter
#
# Dan Bogan convict m
# Ottmar Hörl artist m
#
# Mike Brubaker politician m
# Yuri Herrera writer m
#
# Michael Quante philosopher m
# Ryan Brehm golf
#
# DOUGLASCOSTA soccer
# Forward-Guard16 basketball
#
# Forward50 basketball
# Neil Seery fighter
#
# ALIALBULAYHI soccer
# Afewerk Tekle artist m
#
# FedericoFAZIO soccer
# Rico Malvar computer scientist m
#
# Alexandre Padilha physician m
# Gilles Simon tennis
#
# BlasPEREZ soccer
# Thiago Alves fighter
#
# Carlos Vergés Roger physician m
# Fernando García Casas philosopher m
#
# Malek Shojaee philosopher m
# Miguel Ángel Gil Marín businessperson m
#
# Iñaki Urdangarin convict m
# Phil Mickelson golf
#
# James Gardner musician m
# Thangar Bachan actor m
#
# Milos Raonic tennis
# Paul Stankowski golf
#
# Dicky Pride golf
# Mikkel Rønnow musician m
#
# Gilles Simon tennis
# Morteza Agha-Tehrani politician m
#
# Andrei Molodkin artist m
# David Curtiss Stephenson convict m
#
# Daniel Maeztu politician m
# TomROGIC soccer
#
# Moisés Selman physician m
# Till Tantau computer scientist m
#
# Michael Chiesa fighter
# Olivier Chantreau actor m
#
# Jim Furyk golf
# Joan Maria Thomàs writer m
#
# Adam Wieczorek fighter
# PauloDYBALA soccer
#
# Joshua Cohen philosopher m
# Peter Marggraf artist m
#
# Bob Murphy golf
# Luziano Mitxelena businessperson m
#
# Alberto Mina fighter
# EmilHALLFREDSSON soccer
#
# Lucas Pouille tennis
# Shane Young fighter
#
# MarcosACUNA soccer
# Martin H. Hiller businessperson m
#
# Bronson Burgoon golf
# Simón Pedro Barceló Vadell businessperson m
#
# Billy Hurley III golf
# Douglas Den Uyl philosopher m
#
# Hans J. Pongratz writer m
# Kevin Scott computer scientist m
#
# Charlie Mars musician m
# Chris Riley golf
#
# Antonio Marín Muñoz writer m
# Momo Djender musician m
#
# LuisSUAREZ soccer
# Thierry Beinstingel writer m
#
# Russ Cochran golf
# Stephane Robert tennis
#
# Oliver Sven Schatta politician m
# Stein Helge Glad Nordahl physician m
#
# Peter Uihlein golf
# Stipe Miocic fighter
#
# Daniel Sjölin writer m
# Jorge Petraglia actor m
#
# Curtis Luck golf
# Horacio Cerutti Guldberg philosopher m
#
# Douglas Crockford computer scientist m
# Neil Faulkner writer m
#
# Olusegun Johnson actor m
# U Rajesh Naik politician m
#
# Giuma Ahmed Atigha politician m
# José Luis Gilarranz physician m
#
# Philip Giordano convict m
# Ross H. Stanfield businessperson m
#
# Shane Lowry golf
# Tom Bissell actor m
#
# Andrew Svoboda golf
# David Solomon artist m
#
# MARWANMOHSEN soccer
# Maciej Kujawski actor m
#
# Guard188 basketball
# Laurent Turcot writer m
#
# Mark Humphrey artist m
# Robert Allenby golf
#
# Bennett Foddy philosopher m
# Webb Simpson golf
#
# J.P. Hayes golf
# Juan Ignacio Entrecanales Franco businessperson m

# %%
# # DBSCAN

# start_time = time.time()

# clustering = DBSCAN(eps=1, min_samples= 3).fit(X)
# DBSCAN_cluster = get_clusters_dict(clustering.labels_)

# print(clustering.labels_)
# print("\n")
# print(len(DBSCAN_cluster))
# print("\n")
# DBSCAN_label_pairs = create_label_pairs(DBSCAN_cluster)

# f_measure(true_label_pairs, DBSCAN_label_pairs, "DBSCAN")

# print("--- %s seconds ---" % (time.time() - start_time))

# print()

# # Affinity Propagation
# start_time = time.time()

# clustering = AffinityPropagation().fit(X)

# ap_clusters = get_clusters_dict(clustering.labels_)

# print(len(ap_clusters))

# ap_label_pairs = create_label_pairs(ap_clusters)

# f_measure(true_label_pairs, ap_label_pairs, "Affinity Porpagation")

# print("--- %s seconds ---" % (time.time() - start_time))

# print()

# # Mean shift

# start_time = time.time()

# clustering = MeanShift(bandwidth=1).fit(X)

# mean_shift_cluster = get_clusters_dict(clustering.labels_)

# print(clustering.labels_)
# print("\n")
# print(len(mean_shift_cluster))
# print("\n")
# mean_shift_label_pairs = create_label_pairs(mean_shift_cluster)

# f_measure(true_label_pairs, mean_shift_label_pairs, "Mean Shift")

# print("--- %s seconds ---" % (time.time() - start_time))

# %%
# pca = PCA(n_components=2)
# principalComponents = pca.fit_transform(X)
# reduced_centroids = pca.fit_transform(kmeans.cluster_centers_)

# colors = ["#ffe119", "#f032e6", "#9A6324", "#3cb44b", "#e6194B", "#f58231", "#ffe119", "#469990", "#42d4f4", "#4363d8", "#911eb4"]

# # plt.scatter(X[:,0], X[:,1], s=5)

# for i in kmeans.labels_:
#     color = colors[i]
#     for feature in principalComponents[kmeans.labels_ == i]:
#         plt.scatter(feature[0], feature[1], marker="x", color=color, s=5, linewidths=5)
#     plt.scatter(reduced_centroids[i][0], reduced_centroids[i][1], marker="o", color=color, edgecolors='black',  s=30, linewidths=1)

# plt.show()
